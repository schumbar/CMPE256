# %% [markdown]
# # Assignment 1
# Hierarchical Clustering (Agglomerative) Single Link
#
# Shawn Chumbar
#
# CMPE 256
#
# [Homework Prompt Link](https://sjsu.instructure.com/courses/1576186/assignments/6775146)
#
# Sources:
# Please see below for a list of resources that I used for assistance for this homework assignment:
# 1. https://medium.com/@MaheshGadakari/hierarchical-agglomerative-clustering-hac-with-single-linkage-method-1159fa623d52
# 2. https://www.youtube.com/watch?v=8QCBl-xdeZI&ab_channel=DATAtab
# 3. https://datatab.net/statistics-calculator/cluster/hierarchical-cluster-analysis-calculator
# 4. https://www.youtube.com/watch?v=oNYtYm0tFso&ab_channel=MaheshHuddar
# 5. https://www.kaggle.com/code/barelydedicated/hierarchical-clustering-single-link
# 6. https://www.youtube.com/watch?v=8QCBl-xdeZI&ab_channel=DATAtab
# 7. https://people.revoledu.com/kardi/tutorial/Clustering/Online-Hierarchical-Clustering.html
# 8. https://www.youtube.com/watch?v=IdrlgvE_R08&ab_channel=BartoszCzapiewski
# 9. Excel to keep track of the distance matrices
# 10. ChatGPT (Approved by Professor)

# %%
# !pip install matplotlib
# !pip install numpy
# !pip install scipy

# %%
import numpy as np
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

# %%
data_points = np.array([
    (3,7),
    (2,6),
    (2,2),
    (5,8),
    (6,6),
    (5,5),
    (8,4),
    (7,3),
    (5,2),
    (10,6),
    (12,8)
])

# %% [markdown]
# ### Single Link

# %%
labels = [f"({x},{y})" for x, y in data_points]

# Plot dendrogram for single linkage with coordinate labels
linked_single = linkage(data_points, method='single')
plt.figure(figsize=(10, 5))
dendrogram(linked_single, labels=labels, truncate_mode='lastp', p=12)
plt.title('Dendrogram (Single Linkage)')
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# ### Complete Link

# %%
# Plot dendrogram for complete linkage with coordinate labels
linked_complete = linkage(data_points, method='complete')
plt.figure(figsize=(10, 5))
dendrogram(linked_complete, labels=labels, truncate_mode='lastp', p=12)
plt.title('Dendrogram (Complete Linkage)')
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# ### Average Link

# %%
# Plot dendrogram for average linkage with coordinate labels
linked_average = linkage(data_points, method='average')
plt.figure(figsize=(10, 5))
dendrogram(linked_average, labels=labels, truncate_mode='lastp', p=12)
plt.title('Dendrogram (Average Linkage)')
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.show()
